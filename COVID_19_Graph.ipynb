# %% [markdown]
# # COVID-19 Animated Bar Chart

# %%
pip install plotly==4.5.2
# Out:
# Requirement already satisfied: plotly==4.5.2 in /usr/local/lib/python3.6/dist-packages (4.5.2)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly==4.5.2) (1.3.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly==4.5.2) (1.12.0)

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
import plotly
plotly.__version__
# Out:
# '4.5.2'

# %% [markdown]
# ## 1. Read CSV

# %%
# Use pandas read_csv method to parse csv file
covid_19 = pd.read_csv("covid_19_data.csv", date_parser=True)

# %%
# Inspect first 20 rows of datasets
covid_19.head(20)
# Out:
#     SNo ObservationDate  Province/State  ... Confirmed Deaths  Recovered
# 0     1      01/22/2020           Anhui  ...       1.0    0.0        0.0
# 1     2      01/22/2020         Beijing  ...      14.0    0.0        0.0
# 2     3      01/22/2020       Chongqing  ...       6.0    0.0        0.0
# 3     4      01/22/2020          Fujian  ...       1.0    0.0        0.0
# 4     5      01/22/2020           Gansu  ...       0.0    0.0        0.0
# 5     6      01/22/2020       Guangdong  ...      26.0    0.0        0.0
# 6     7      01/22/2020         Guangxi  ...       2.0    0.0        0.0
# 7     8      01/22/2020         Guizhou  ...       1.0    0.0        0.0
# 8     9      01/22/2020          Hainan  ...       4.0    0.0        0.0
# 9    10      01/22/2020           Hebei  ...       1.0    0.0        0.0
# 10   11      01/22/2020    Heilongjiang  ...       0.0    0.0        0.0
# 11   12      01/22/2020           Henan  ...       5.0    0.0        0.0
# 12   13      01/22/2020       Hong Kong  ...       0.0    0.0        0.0
# 13   14      01/22/2020           Hubei  ...     444.0   17.0       28.0
# 14   15      01/22/2020           Hunan  ...       4.0    0.0        0.0
# 15   16      01/22/2020  Inner Mongolia  ...       0.0    0.0        0.0
# 16   17      01/22/2020         Jiangsu  ...       1.0    0.0        0.0
# 17   18      01/22/2020         Jiangxi  ...       2.0    0.0        0.0
# 18   19      01/22/2020           Jilin  ...       0.0    0.0        0.0
# 19   20      01/22/2020        Liaoning  ...       2.0    0.0        0.0
#
# [20 rows x 8 columns]

# %%
# Confirmed case in each country, descending order
country = covid_19.groupby("Country/Region", as_index=False).sum().sort_values("Confirmed", ascending=False)
country
# Out:
#       Country/Region       SNo  Confirmed    Deaths  Recovered
# 122   Mainland China  10461980  4829567.0  172245.0  2997441.0
# 205               US  17625603  3657903.0   92199.0   143637.0
# 100            Italy    332079  2217867.0  240848.0   317538.0
# 186            Spain    333600  1762565.0  152262.0   387132.0
# 75           Germany    332973  1363130.0   16381.0   300324.0
# ..               ...       ...        ...       ...        ...
# 41   Channel Islands      4686        1.0       0.0        0.0
# 37        Cape Verde      7585        1.0       0.0        0.0
# 57        East Timor      7589        1.0       0.0        0.0
# 198       The Gambia     35095        1.0       0.0        0.0
# 0         Azerbaijan      2664        1.0       0.0        0.0
#
# [219 rows x 5 columns]

# %%
# Top 20 Countries corresponding to confirmed case
top20 = country["Country/Region"].head(20)
top20
# Out:
# 122    Mainland China
# 205                US
# 100             Italy
# 186             Spain
# 75            Germany
# 69             France
# 96               Iran
# 204                UK
# 184       South Korea
# 192       Switzerland
# 203            Turkey
# 141       Netherlands
# 20            Belgium
# 12            Austria
# 36             Canada
# 159          Portugal
# 27             Brazil
# 99             Israel
# 191            Sweden
# 148            Norway
# Name: Country/Region, dtype: object

# %%
top20.values
# Out:
# array(['Mainland China', 'US', 'Italy', 'Spain', 'Germany', 'France',
#        'Iran', 'UK', 'South Korea', 'Switzerland', 'Turkey',
#        'Netherlands', 'Belgium', 'Austria', 'Canada', 'Portugal',
#        'Brazil', 'Israel', 'Sweden', 'Norway'], dtype=object)

# %%
# Index to be padded because not all country have the same date index
pad_index = covid_19[covid_19["Country/Region"] == "Mainland China"].groupby("ObservationDate").sum().index
pad_index
# Out:
# Index(['01/22/2020', '01/23/2020', '01/24/2020', '01/25/2020', '01/26/2020',
#        '01/27/2020', '01/28/2020', '01/29/2020', '01/30/2020', '01/31/2020',
#        '02/01/2020', '02/02/2020', '02/03/2020', '02/04/2020', '02/05/2020',
#        '02/06/2020', '02/07/2020', '02/08/2020', '02/09/2020', '02/10/2020',
#        '02/11/2020', '02/12/2020', '02/13/2020', '02/14/2020', '02/15/2020',
#        '02/16/2020', '02/17/2020', '02/18/2020', '02/19/2020', '02/20/2020',
#        '02/21/2020', '02/22/2020', '02/23/2020', '02/24/2020', '02/25/2020',
#        '02/26/2020', '02/27/2020', '02/28/2020', '02/29/2020', '03/01/2020',
#        '03/02/2020', '03/03/2020', '03/04/2020', '03/05/2020', '03/06/2020',
#        '03/07/2020', '03/08/2020', '03/09/2020', '03/10/2020', '03/11/2020',
#        '03/12/2020', '03/13/2020', '03/14/2020', '03/15/2020', '03/16/2020',
#        '03/17/2020', '03/18/2020', '03/19/2020', '03/20/2020', '03/21/2020',
#        '03/22/2020', '03/23/2020', '03/24/2020', '03/25/2020', '03/26/2020',
#        '03/27/2020', '03/28/2020', '03/29/2020', '03/30/2020', '03/31/2020',
#        '04/01/2020', '04/02/2020', '04/03/2020', '04/04/2020', '04/05/2020',
#        '04/06/2020', '04/07/2020', '04/08/2020'],
#       dtype='object', name='ObservationDate')

# %%
#
# Select each country rows
# Pad the rows
# Stack the rows

# %% [markdown]
# Declare a function to arange data frame.
# What it will do:
# 1. Copy the data frame to avoid overwriting.
# 2. Create rows for every country
# 3. Pad the rows with the previous pad_index.
# 4. Add another columns containing country name and date.
# 5. Fill the NaN (not a number) rows with 0 because padded rows will be filled with NaN.

# %%
def arrangeData(df, countries, pad_index):
    dfCopy = df.copy()
    pad = pad_index.copy()
    rowList = []
    
    for country in countries:
        rows = dfCopy[dfCopy["Country/Region"] == country].groupby("ObservationDate", as_index=False).sum()
        rows = rows.set_index("ObservationDate")
        rows = rows.reindex(pad)
        rows["Country"] = country
        rows["Dates"] = rows.index
        rows.fillna(0, inplace=True)
        rowList.append(rows)
        
    dfNew = pd.concat(rowList, axis=0)
    return dfNew

covid_aranged = arrangeData(covid_19, top20.values, pad_index)
covid_aranged
# Out:
#                      SNo  Confirmed  ...         Country       Dates
# ObservationDate                      ...
# 01/22/2020         535.0      547.0  ...  Mainland China  01/22/2020
# 01/23/2020        1713.0      639.0  ...  Mainland China  01/23/2020
# 01/24/2020        3004.0      916.0  ...  Mainland China  01/24/2020
# 01/25/2020        4224.0     1399.0  ...  Mainland China  01/25/2020
# 01/26/2020        5548.0     2062.0  ...  Mainland China  01/26/2020
# ...                  ...        ...  ...             ...         ...
# 04/04/2020       11737.0     5550.0  ...          Norway  04/04/2020
# 04/05/2020       12053.0     5687.0  ...          Norway  04/05/2020
# 04/06/2020       12372.0     5865.0  ...          Norway  04/06/2020
# 04/07/2020       12692.0     6086.0  ...          Norway  04/07/2020
# 04/08/2020       13012.0     6086.0  ...          Norway  04/08/2020
#
# [1560 rows x 6 columns]

# %% [markdown]
# Visualization part with plotly library.
# It takes data frame and its columns as arguments.

# %%
fig = px.bar(covid_aranged, x="Confirmed", y="Country", 
             orientation='h', color="Country", animation_frame="Dates",
             animation_group="Country", range_x=[0, 500000])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cfe72a9c-bfa6-440f-a64f-6e9ca8afe822" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cfe72a9c-bfa6-440f-a64f-6e9ca8afe822")) {
#                     Plotly.newPlot(
#                         'cfe72a9c-bfa6-440f-a64f-6e9ca8afe822',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["Mainland China"], "legendgroup": "Mainland China", "marker": {"color": "#636efa"}, "name": "Mainland China", "offsetgroup": "Mainland China", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [547.0], "xaxis": "x", "y": ["Mainland China"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["US"], "legendgroup": "US", "marker": {"color": "#EF553B"}, "name": "US", "offsetgroup": "US", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1.0], "xaxis": "x", "y": ["US"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["Italy"], "legendgroup": "Italy", "marker": {"color": "#00cc96"}, "name": "Italy", "offsetgroup": "Italy", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0], "xaxis": "x", "y": ["Italy"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["Spain"], "legendgroup": "Spain", "marker": {"color": "#ab63fa"}, "name": "Spain", "offsetgroup": "Spain", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0], "xaxis": "x", "y": ["Spain"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["Germany"], "legendgroup": "Germany", "marker": {"color": "#FFA15A"}, "name": "Germany", "offsetgroup": "Germany", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0], "xaxis": "x", "y": ["Germany"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["France"], "legendgroup": "France", "marker": {"color": "#19d3f3"}, "name": "France", "offsetgroup": "France", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0], "xaxis": "x", "y": ["France"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["Iran"], "legendgroup": "Iran", "marker": {"color": "#FF6692"}, "name": "Iran", "offsetgroup": "Iran", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0], "xaxis": "x", "y": ["Iran"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["UK"], "legendgroup": "UK", "marker": {"color": "#B6E880"}, "name": "UK", "offsetgroup": "UK", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0], "xaxis": "x", "y": ["UK"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["South Korea"], "legendgroup": "South Korea", "marker": {"color": "#FF97FF"}, "name": "South Korea", "offsetgroup": "South Korea", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [1.0], "xaxis": "x", "y": ["South Korea"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Country=%{y}<br>Dates=01/22/2020<br>Confirmed=%{x}", "ids": ["Switzerland"], "legendgroup": "Switzerland", "marker": {"color": "#FECB52"}, "name": "Switzerland", "offsetgroup": "Switzerland", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [0.0], "xaxis": "x", "y": ["Switzerland"], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hoverte ...
